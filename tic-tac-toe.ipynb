# %%
import random

def print_board_in_rowsColumns(board):
    for i, row in enumerate(board):
        print(" | ".join(row))
        if i < 2:
            print("-" * 9)
    print("\n")

def check_winner(board, player):
    for i in range(3):
        if all(board[i][j] == player for j in range(3)) or \
           all(board[j][i] == player for j in range(3)):
            return True
    return all(board[i][i] == player for i in range(3)) or \
           all(board[i][2 - i] == player for i in range(3))

def board_full(board):
    return all(board[i][j] != ' ' for i in range(3) for j in range(3))

def get_empty_cells(board):
    return [(i, j) for i in range(3) for j in range(3) if board[i][j] == ' ']

def make_ai_move(board):
    empty_cells = get_empty_cells(board)
    return random.choice(empty_cells)

def get_user_move():
    while True:
        try:
            row, col = map(int, input("Enter your move (row and column, separated by space): ").split())
            if 0 <= row <= 2 and 0 <= col <= 2:
                return row, col
            else:
                print("Invalid move. Please enter row and column indices between 0 and 2.")
        except ValueError:
            print("Invalid input. Please enter two integers separated by space.")

def play_tic_tac_toe_game_byShafiya():
    board = [[' ' for _ in range(3)] for _ in range(3)]
    players = ['X', 'O']
    current_player = random.choice(players)

    while True:
        print_board_in_rowsColumns(board)

        if current_player == 'X':
            row, col = get_user_move()
            if board[row][col] == ' ':
                board[row][col] = 'X'
            else:
                print("Invalid move. Try again.")
                continue
        else:
            row, col = make_ai_move(board)
            board[row][col] = 'O'

        if check_winner(board, current_player):
            print_board_in_rowsColumns(board)
            print(f"{current_player} wins!")
            break
        elif board_full(board):
            print_board(board)
            print("It's a tie!")
            break

        current_player = 'O' if current_player == 'X' else 'X'
        print("\n" * 2)  # Add extra spaces between each stage

play_tic_tac_toe_game_byShafiya()
# Out:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
#
#
#
#
#
#   |   |
# ---------
#   |   |
# ---------
# O |   |
#
#
# Enter your move (row and column, separated by space): 0 1
#
#
#
#   | X |
# ---------
#   |   |
# ---------
# O |   |
#
#
#
#
#
#   | X |
# ---------
#   |   |
# ---------
# O | O |
#
#
# Enter your move (row and column, separated by space): 0 0
#
#
#
# X | X |
# ---------
#   |   |
# ---------
# O | O |
#
#
#
#
#
# X | X |
# ---------
#   | O |
# ---------
# O | O |
#
#
# Enter your move (row and column, separated by space): 0 2
# X | X | X
# ---------
#   | O |
# ---------
# O | O |
#
#
# X wins!
